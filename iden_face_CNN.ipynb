# %% [markdown]
# <a href="https://colab.research.google.com/github/leminhquoc248/AI_code/blob/main/iden_face_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Khai báo và sử dụng các thư viện sau
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop,Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/AI/Bai4/Train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 144 images belonging to 3 classes.

# %%
validation=train_datagen.flow_from_directory('/content/drive/MyDrive/AI/Bai4/Test',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 47 images belonging to 3 classes.

# %%
training_set.class_indices
# Out:
# {'Cuong': 0, 'Dat': 1, 'Quoc': 2}

# %%
model=Sequential()
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 128)               5308544
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 5,595,939
# Trainable params: 5,595,939
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt=SGD(lr=0.01,momentum=0.9)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])
history=model.fit(training_set,epochs=100,batch_size=10,verbose=1, validation_data=validation, callbacks=[EarlyStopping(monitor='val_loss', patience=20)]) # verbose=1 để hiển thị quá trinh học
# Out:
# Epoch 1/100
# 5/5 [==============================] - 49s 9s/step - loss: 2.0686 - accuracy: 0.4375 - val_loss: 0.9597 - val_accuracy: 0.3404
# Epoch 2/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.6809 - accuracy: 0.7917 - val_loss: 0.2193 - val_accuracy: 0.9787
# Epoch 3/100
# 5/5 [==============================] - 2s 375ms/step - loss: 0.1342 - accuracy: 0.9653 - val_loss: 0.2734 - val_accuracy: 0.8511
# Epoch 4/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.1971 - accuracy: 0.9444 - val_loss: 0.0333 - val_accuracy: 1.0000
# Epoch 5/100
# 5/5 [==============================] - 2s 392ms/step - loss: 0.1261 - accuracy: 0.9583 - val_loss: 9.0292e-04 - val_accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 2s 375ms/step - loss: 0.1025 - accuracy: 0.9722 - val_loss: 0.0284 - val_accuracy: 0.9787
# Epoch 7/100
# 5/5 [==============================] - 2s 375ms/step - loss: 0.1235 - accuracy: 0.9583 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 2s 396ms/step - loss: 0.1912 - accuracy: 0.9653 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 2s 428ms/step - loss: 0.0310 - accuracy: 0.9792 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0126 - accuracy: 0.9931 - val_loss: 8.5128e-05 - val_accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0447 - val_accuracy: 0.9787
# Epoch 12/100
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0132 - accuracy: 0.9931 - val_loss: 5.7667e-04 - val_accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0070 - accuracy: 0.9931 - val_loss: 3.3580e-04 - val_accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9787
# Epoch 15/100
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 4.2839e-06 - val_accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 2s 389ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.0068e-05 - val_accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 2s 384ms/step - loss: 7.1381e-05 - accuracy: 1.0000 - val_loss: 6.1671e-05 - val_accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 2s 385ms/step - loss: 3.1538e-04 - accuracy: 1.0000 - val_loss: 2.1449e-05 - val_accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 2s 387ms/step - loss: 1.4841e-04 - accuracy: 1.0000 - val_loss: 1.0142e-05 - val_accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0111 - accuracy: 0.9931 - val_loss: 4.4106e-06 - val_accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] -
-08 - val_accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 2s 391ms/step - loss: 1.3270e-06 - accuracy: 1.0000 - val_loss: 5.0727e-09 - val_accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 2s 381ms/step - loss: 1.3598e-05 - accuracy: 1.0000 - val_loss: 4.0074e-07 - val_accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 2s 384ms/step - loss: 2.1919e-05 - accuracy: 1.0000 - val_loss: 7.8627e-08 - val_accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 2s 371ms/step - loss: 9.9297e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 2s 369ms/step - loss: 4.1568e-05 - accuracy: 1.0000 - val_loss: 1.6384e-06 - val_accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 2s 377ms/step - loss: 3.5381e-05 - accuracy: 1.0000 - val_loss: 4.2611e-07 - val_accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 2s 373ms/step - loss: 3.5785e-05 - accuracy: 1.0000 - val_loss: 1.6486e-07 - val_accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 2s 433ms/step - loss: 2.4784e-05 - accuracy: 1.0000 - val_loss: 1.2682e-07 - val_accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 2s 371ms/step - loss: 1.0720e-04 - accuracy: 1.0000 - val_loss: 1.4381e-06 - val_accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 2s 424ms/step - loss: 1.9140e-04 - accuracy: 1.0000 - val_loss: 2.5364e-09 - val_accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 2s 429ms/step - loss: 4.4786e-07 - accuracy: 1.0000 - val_loss: 3.2514e-06 - val_accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 2s 427ms/step - loss: 5.2908e-04 - accuracy: 1.0000 - val_loss: 7.6091e-09 - val_accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 2s 371ms/step - loss: 0.0061 - accuracy: 0.9931 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0221 - accuracy: 0.9931 - val_loss: 4.1835e-05 - val_accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0133 - accuracy: 0.9931 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0580 - accuracy: 0.9792 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0206 - accuracy: 0.9931 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 2s 425ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0281 - accuracy: 0.9861 - val_loss: 5.4854e-05 - val_accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 2s 366ms/step - loss: 0.0158 - accuracy: 0.9931 - val_loss: 3.4289e-04 - val_accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0332 - accuracy: 0.9931 - val_loss: 9.2323e-07 - val_accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0118 - accuracy: 0.9931 - val_loss: 1.6233e-07 - val_accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 2s 428ms/step - loss: 8.7357e-05 - accuracy: 1.0000 - val_loss: 8.0149e-07 - val_accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0435 - accuracy: 0.9931 - val_loss: 4.6162e-07 - val_accuracy: 1.0000

# %%
# Đánh giá độ chính xác của mô hình sau khi đã train 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 1.1187539712409489e-05
# Train Accuracy 1.0

# %%
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Lưu lại
model.save("Final.h5")
model_CNN=load_model('Final.h5')

# %%
img=load_img('/content/drive/MyDrive/AI/Bai4/Pic/dat.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,150,150,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='Cuong'
elif round(result[0][1])==1:
  prediction='Dat'
elif round(result[0][2])==1:
  prediction='Quoc'
print(prediction)
# Out:
# Dat

# %%
img=load_img('/content/drive/MyDrive/AI/Bai4/Pic/cuong1.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,150,150,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='Cuong'
elif round(result[0][1])==1:
  prediction='Dat'
elif round(result[0][2])==1:
  prediction='Quoc'
print(prediction)
# Out:
# Quoc
